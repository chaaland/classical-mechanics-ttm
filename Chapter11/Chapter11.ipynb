# %%
using PyPlot;

# %% [markdown]
# # Exercise 1
# Confirm $\left(V\times A\right)_i = \sum_k\sum_j \epsilon_{ijk}V_jA_k$. Also prove that $V_iA_j - V_jA_i = \sum_k \epsilon_{ijk}(V\times A)_i$

# %% [markdown]
# ## Solution
#
# From the definiton of the cross product
# $$
# \begin{align*}
# V \times A &= (V_yA_z - V_zA_y)\hat{i} + (V_zA_x - V_xA_z)\hat{j}+(V_xA_y - V_yA_x)\hat{k}\\
# &= (\epsilon_{xyz}V_yA_z + \epsilon_{xzy}V_zA_y)\hat{i} + (\epsilon_{yzx}V_zA_x + \epsilon_{yxz}V_xA_z)\hat{j}+(\epsilon_{zxy}V_xA_y + \epsilon_{zyx}V_yA_x)\hat{k}\\
# \end{align*}
# $$

# %% [markdown]
# # Exercise 2
# Prove $\nabla \times (\nabla V) = 0$

# %% [markdown]
# ## Solution
#
# $\nabla V$ is given by $\frac{\partial V}{\partial x}\hat{i}+\frac{\partial V}{\partial y}\hat{j}+\frac{\partial V}{\partial z}\hat{k}$.
#
# The components of the curl are
#
# $$
# \begin{align*}
# \mathbf{curl}(\nabla V)_x &= \frac{\partial }{\partial y}\frac{\partial V}{\partial z} - \frac{\partial }{\partial z}\frac{\partial V}{\partial y}\\
# &= 0\\
# \mathbf{curl}(\nabla V)_y &= \frac{\partial }{\partial z}\frac{\partial V}{\partial x} - \frac{\partial }{\partial x}\frac{\partial V}{\partial z}\\
# &= 0\\
# \mathbf{curl}(\nabla V)_z &= \frac{\partial }{\partial x}\frac{\partial V}{\partial y} - \frac{\partial }{\partial y}\frac{\partial V}{\partial x}\\
# &= 0\\
# \end{align*}
# $$

# %% [markdown]
# # Exercise 3
# Show that the vector potentials $A = (0,bx,0)$ and $A'=(-by,0,0)$ both give the same uniform magnetic field. This means that the two differ by a gradient. Find the scalar whose gradient, when added to $A$, gives $A'$

# %% [markdown]
# ## Solution
#
# The magnetic field is given by the curl of the vector potential $A$.
# $$
# \begin{align*}
# \mathbf{curl}(A) &= \left(\frac{\partial (0)}{\partial y} - \frac{\partial (bx)}{\partial z} \right)\hat{i} +\left(\frac{\partial (0)}{\partial z} - \frac{\partial (0)}{\partial x} \right)\hat{j}+\left(\frac{\partial (bx)}{\partial x} - \frac{\partial (0)}{\partial y} \right)\hat{k}\\
# &= b\hat{k}\\
# \mathbf{curl}(\hat{A}) &= \left(\frac{\partial (0)}{\partial y} - \frac{\partial (0)}{\partial z} \right)\hat{i} +\left(\frac{\partial (-by)}{\partial z} - \frac{\partial (0)}{\partial x} \right)\hat{j}+\left(\frac{\partial (0)}{\partial x} - \frac{\partial (-by)}{\partial y} \right)\hat{k}\\
# &= b\hat{k}\\
# \end{align*}
# $$
#
# The curls of $A$ and $\hat{A}$ are identical.
#
# Since $\mathbf{curl}(\nabla f) = 0$, and $\mathbf{curl}(A) = \mathbf{curl}(A')$, then $A + \nabla f = A'$. By inspection $f(x,y,z) = -bxy$

# %% [markdown]
# # Exercise 4
# Using the Hamiltonian,
# $$H = \sum_i \left\{\frac{1}{2m}\left[p_i-\frac{e}{c}A_i(x)\right]\left[p_i-\frac{e}{c}A_i(x)\right]\right\}$$
# work out Hamilton's equations of motion and show that you get the Newton-Lorentz equation of motion.

# %% [markdown]
# ## Solution
#
# Hamilton's equations are
#
# $$
# \begin{align*}
# \dot{q} &= \frac{\partial H}{\partial p}\\
# \dot{p} &= -\frac{\partial H}{\partial q}\\
# \end{align*}
# $$
#
# Plugging in the given Hamiltonian,
# $$
# \begin{align*}
# \dot{q}_i &= \frac{2}{2m}(p_i-e/cA_i(q))\\
# &= \frac{1}{m}(p_i-e/cA_i(q))\\
# \dot{p}_i &= \frac{2e}{2mc}\sum_{k}(p_k-e/cA_k(q))\frac{\partial A_k(q)}{\partial q_i}\\
# &= \frac{e}{mc}\sum_{k}(p_k-e/cA_k(q))\frac{\partial A_k(q)}{\partial q_i}\\
# \end{align*}
# $$

# %% [markdown]
# Taking the derivative of $\dot{q}_i$ gives
#
# $$
# \begin{align*}
# \ddot{q}_i &= \frac{1}{m}\left(\dot{p}_i-e/c\sum_k \frac{\partial A_i(q)}{\partial q_k}\dot{q}_k\right)\\
# &= \frac{1}{m}\left(\frac{e}{mc}\sum_{k}(p_k-e/cA_k(q))\frac{\partial A_k(q)}{\partial q_i}-e/c\sum_k \frac{\partial A_i(q)}{\partial q_k}\dot{q}_k\right)\\
# &= \frac{1}{m}\left(\frac{e}{mc}\sum_{k}(m\dot{q}_k+e/cA_k(q)-e/cA_k(q))\frac{\partial A_k(q)}{\partial q_i}-e/c\sum_k \frac{\partial A_i(q)}{\partial q_k}\dot{q}_k\right)\\
# &= \frac{1}{m}\left(\frac{e}{c}\sum_{k}\dot{q}_k\frac{\partial A_k(q)}{\partial q_i}-e/c\sum_k \frac{\partial A_i(q)}{\partial q_k}\dot{q}_k\right)\\
# \end{align*}
# $$

# %% [markdown]
# $$
# \begin{align*}
# \ddot{q}_x &= \frac{e}{mc}\left[\left(\frac{\partial A_y(q)}{\partial q_x}-\frac{\partial A_x(q)}{\partial q_y}\right)\dot{q}_y + \left(\frac{\partial A_z(q)}{\partial q_x}-\frac{\partial A_x(q)}{\partial q_z}\right)\dot{q}_z\right]\\
# &= \frac{e}{mc}(B_z\dot{q}_y-B_y\dot{q}_z)\\
# \ddot{q}_y &= \frac{e}{mc}\left[\left(\frac{\partial A_x(q)}{\partial q_y}-\frac{\partial A_y(q)}{\partial q_x}\right)\dot{q}_x + \left(\frac{\partial A_z(q)}{\partial q_y}-\frac{\partial A_y(q)}{\partial q_z}\right)\dot{q}_z\right]\\
# &= \frac{e}{mc}(-B_z\dot{q}_x+B_y\dot{q}_z)\\
# \ddot{q}_z &= \frac{e}{mc}\left[\left(\frac{\partial A_x(q)}{\partial q_z}-\frac{\partial A_z(q)}{\partial q_x}\right)\dot{q}_x + \left(\frac{\partial A_y(q)}{\partial q_z}-\frac{\partial A_z(q)}{\partial q_y}\right)\dot{q}_y\right]\\
# &= \frac{e}{mc}(B_y\dot{q}_x-B_x\dot{q}_y)\\
# \end{align*}
# $$
#
# From the definition of the cross product, this gives
# $$\ddot{q} = \frac{e}{mc}v\times B$$
# which is exactly the Lorentz force law

# %% [markdown]
# # Exercise 5
#
# Show that in the $x$,$y$ plane, the solution to $a_y=-\frac{eb}{mc}v_x$ and the solution to $a_x = \frac{eb}{mc}v_y$ are a circular orbit with the center of the orbit being anywhere on the plane. Find the radius of the orbit in terms of the velocity.

# %% [markdown]
# ## Solution
#
# The equations of motion are
# $$
# \frac{\mathrm{d}}{\mathrm{d}t}
# \left(
# \begin{bmatrix}
# v_x\\
# v_y
# \end{bmatrix}\right)
# =
# \frac{eb}{mc}
# \begin{bmatrix}
# 0 & 1\\
# -1 & 0\\
# \end{bmatrix}
# \begin{bmatrix}
# v_x\\
# v_y
# \end{bmatrix}
# $$

# %% [markdown]
# The solution is given by the matrix exponential $v(t) = \exp(t A)v(0)$ where $A$ is the above matrix. Which has eigenvalue decomposition
#
# $$
# A = \frac{eb}{mc}
# \begin{bmatrix}
# \frac{1}{\sqrt{2}} & \frac{1}{\sqrt{2}}\\
# \frac{-i}{\sqrt{2}} & \frac{i}{\sqrt{2}}\\
# \end{bmatrix}
# \begin{bmatrix}
# -i & 0\\
# 0 & i\\
# \end{bmatrix}
# \begin{bmatrix}
# \frac{1}{\sqrt{2}} & \frac{i}{\sqrt{2}}\\
# \frac{1}{\sqrt{2}} & \frac{-i}{\sqrt{2}}\\
# \end{bmatrix}
# $$
#
# So the velocity is given by
# $$
# \begin{align*}
# v(t) &= \exp(tA)v(0)\\
# &= \exp(tCDC^{-1})v(0)\\
# &= \left(\sum_{k=0}^\infty (t^k(CDC^{-1})^k/k!\right)v(0)\\
# &= C\left(\sum_{k=0}^\infty t^kD^k/k!\right)C^{-1}v(0)\\
# &=
# C
# \left(
# \sum_{k=0}^\infty \left(t\frac{eb}{mc}\right)^k
#  \begin{bmatrix}
# \frac{(-i)^k}{k!} & 0\\
# 0 & \frac{i^k}{k!}\\
# \end{bmatrix}
# \right)
# C^{-1}v(0)\\
# &=
# C
#  \begin{bmatrix}
# \sum_{k=0}^\infty \left(t\frac{eb}{mc}\right)^k\frac{(-i)^k}{k!} & 0\\
# 0 & \sum_{k=0}^\infty \left(t\frac{eb}{mc}\right)^k\frac{i^k}{k!}\\
# \end{bmatrix}
# C^{-1}v(0)\\
# &=
# C
#  \begin{bmatrix}
#  \exp\left(-it\frac{eb}{mc}\right) & 0\\
# 0 & \exp\left(it\frac{eb}{mc}\right)\\
# \end{bmatrix}
# C^{-1}v(0)\\
# &=
# C
#  \begin{bmatrix}
#  \frac{1}{\sqrt{2}}\exp\left(-it\frac{eb}{mc}\right) &  \frac{i}{\sqrt{2}}\exp\left(-it\frac{eb}{mc}\right)\\
#  \frac{1}{\sqrt{2}}\exp\left(it\frac{eb}{mc}\right) &  \frac{-i}{\sqrt{2}}\exp\left(it\frac{eb}{mc}\right)\\
# \end{bmatrix}
# v(0)\\
# &=
# \begin{bmatrix}
# \frac{1}{2}\left(\exp\left(it\frac{eb}{mc}\right)+\exp\left(-it\frac{eb}{mc}\right)\right) &  \frac{i}{2}\left(\exp\left(-it\frac{eb}{mc}\right)-\exp\left(it\frac{eb}{mc}\right)\right)\\
#  \frac{-i}{2}\left(\exp\left(-it\frac{eb}{mc}\right)-\exp\left(it\frac{eb}{mc}\right)\right) &  \frac{1}{2}\left(\exp\left(it\frac{eb}{mc}\right)+\exp\left(-it\frac{eb}{mc}\right)\right)\\
# \end{bmatrix}
# v(0)\\
# &=
# \begin{bmatrix}
# \cos\left(t\frac{eb}{mc}\right) &  \sin \left(t\frac{eb}{mc}\right)\\
#  -\sin \left(t\frac{eb}{mc}\right) &  \cos \left(t\frac{eb}{mc}\right)\\
# \end{bmatrix}
# v(0)\\
# \end{align*}
# $$

# %% [markdown]
# The position is then the integral of the velocity
#
# $$
# \begin{align*}
# x(t) &=
# \begin{bmatrix}
# \frac{mc}{eb}\sin\left(t \frac{eb}{mc}\right) & -\frac{mc}{eb}\cos\left(t \frac{eb}{mc}\right) \\
# \frac{mc}{eb}\cos\left(t \frac{eb}{mc}\right) & \frac{mc}{eb}\sin\left(t \frac{eb}{mc}\right)\\
# \end{bmatrix}v(0) + x_c
# \end{align*}
# $$
#
# This is evidently the equation of a circle with center $x_c$ (which depends on the initial conditions) and radius $r=||v(0)||\left(\frac{mc}{eb}\right)$

# %%
q = 1
b = 1
m = 1 
c = 1

x_vals = LinRange(-2, 2, 25)
y_vals = LinRange(-2, 2, 25)

A = q * b / (m * c) * [0 1; -1 0]

figure(figsize=(6,6))
X_mesh = [i for i in x_vals, j in y_vals]
Y_mesh = [j for i in x_vals, j in y_vals]

vx_plot = vec(X_mesh)
vy_plot = vec(Y_mesh)
velocity = hcat(vx_plot, vy_plot)

acceleration = A * velocity'
dx = acceleration[1,:]
dy = acceleration[2,:]

grad_field_norms = [hypot(dx[i],  dy[i]) for i in 1:length(vx_plot)] 
max_norm = maximum(grad_field_norms)
min_norm = minimum(grad_field_norms)

quiver(vx_plot, vy_plot, 
    dx ./ grad_field_norms, dy ./ grad_field_norms, 
    color=PyPlot.cm.viridis((grad_field_norms .- min_norm) / (max_norm - min_norm)), angles="xy");

title("Velocity Field");
xlabel(L"v_x");
ylabel(L"v_y");
# Out:
# Figure(PyObject <Figure size 600x600 with 1 Axes>)

# %%
q = 1
b = 1
m = 1 
c = 1

x_c = vec([0.5 -0.5])
v_0 = vec([0 1])

n_points = 50
t_vals = LinRange(0, 2 * pi, n_points)
x = zeros(2, n_points)

figure(figsize=(6,6))
i = 1
for t in t_vals
    a = (q * b) / (m * c)
    A = 1 / a * [sin(t * a) -cos(t * a); cos(t * a) sin(t * a)]
    x[:, i] = A * v_0 + x_c
    if i % 3 == 0
        B = 1 / a * [cos(t * a) sin(t * a); -sin(t * a) cos(t * a)]
        delta = B * v_0
        arrow(x[1,i], x[2,i], 0.1*delta[1], 0.1*delta[2], shape="full", lw=0, length_includes_head=true, head_width=0.05)
    end
    i += 1
end

plot(x[1,:], x[2,:])
title("Position");
xlabel(L"r_x");
ylabel(L"r_y");
xlim(-2,2);
ylim(-2,2);
# Out:
# Figure(PyObject <Figure size 600x600 with 1 Axes>)
